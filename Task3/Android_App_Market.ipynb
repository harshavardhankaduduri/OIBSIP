# %% [markdown]
# # **Importing the libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Loading the dataset**

# %%
df = pd.read_csv('apps.csv')

# %% [markdown]
# # **number of rows and columns**

# %%
df.shape
# Out:
# (9659, 14)

# %% [markdown]
# # **Check all columns in the dataframe**

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'App', 'Category', 'Rating', 'Reviews', 'Size',
#        'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver'],
#       dtype='object')

# %%
df['Unnamed: 0']
# Out:
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#         ...
# 9654    10836
# 9655    10837
# 9656    10838
# 9657    10839
# 9658    10840
# Name: Unnamed: 0, Length: 9659, dtype: int64

# %% [markdown]
# # **Renaming all the columns in the dataframe**

# %%
new_cols = {
    'Unnamed: 0' : 'unnamed',
    'App' : 'app',
    'Category' : 'category',
    'Rating' : 'rating',
    'Reviews' : 'reviews',
    'Size' : 'size',
    'Installs' : 'installs',
    'Type' : 'type',
    'Price' : 'price',
    'Content Rating' : 'content_rating',
    'Genres' : 'genres',
    'Last Updated' : 'last_updated',
    'Current Ver' : 'current_version',
    'Android Ver' : 'andriod_version'
}
df.rename(columns = new_cols, inplace = True)
df.columns
# Out:
# Index(['unnamed', 'app', 'category', 'rating', 'reviews', 'size', 'installs',
#        'type', 'price', 'content_rating', 'genres', 'last_updated',
#        'current_version', 'andriod_version'],
#       dtype='object')

# %% [markdown]
# # **1. Data Preparation**

# %% [markdown]
# ### **Check the datatype of all columns**

# %%
df.dtypes
# Out:
# unnamed              int64
# app                 object
# category            object
# rating             float64
# reviews              int64
# size               float64
# installs            object
# type                object
# price               object
# content_rating      object
# genres              object
# last_updated        object
# current_version     object
# andriod_version     object
# dtype: object

# %% [markdown]
# ### **Dataframe information**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   unnamed          9659 non-null   int64
#  1   app              9659 non-null   object
#  2   category         9659 non-null   object
#  3   rating           8196 non-null   float64
#  4   reviews          9659 non-null   int64
#  5   size             8432 non-null   float64
#  6   installs         9659 non-null   object
#  7   type             9659 non-null   object
#  8   price            9659 non-null   object
#  9   content_rating   9659 non-null   object
#  10  genres           9659 non-null   object
#  11  last_updated     9659 non-null   object
#  12  current_version  9651 non-null   object
#  13  andriod_version  9657 non-null   object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 1.0+ MB

# %% [markdown]
# ### **Check the missing values in the dataframe**

# %%
df.isna()
# Out:
#       unnamed    app  category  rating  reviews   size  installs   type  \
# 0       False  False     False   False    False  False     False  False
# 1       False  False     False   False    False  False     False  False
# 2       False  False     False   False    False  False     False  False
# 3       False  False     False   False    False  False     False  False
# 4       False  False     False   False    False  False     False  False
# ...       ...    ...       ...     ...      ...    ...       ...    ...
# 9654    False  False     False   False    False  False     False  False
# 9655    False  False     False   False    False  False     False  False
# 9656    False  False     False    True    False  False     False  False
# 9657    False  False     False   False    False   True     False  False
# 9658    False  False     False   False    False  False     False  False
#
#       price  content_rating  genres  last_updated  current_version  \
# ...

# %% [markdown]
# ### **Check the missing values count in the dataframe**

# %%
df.isna().sum()
# Out:
# unnamed               0
# app                   0
# category              0
# rating             1463
# reviews               0
# size               1227
# installs              0
# type                  0
# price                 0
# content_rating        0
# genres                0
# last_updated          0
# current_version       8
# andriod_version       2
# dtype: int64

# %% [markdown]
# ### **Get the missing values count after sorting**

# %%
df.isna().sum().sort_values(ascending = False)
# Out:
# rating             1463
# size               1227
# current_version       8
# andriod_version       2
# unnamed               0
# app                   0
# category              0
# reviews               0
# installs              0
# type                  0
# price                 0
# content_rating        0
# genres                0
# last_updated          0
# dtype: int64

# %% [markdown]
# it contains missing values in attributes like rating,size,current_version,android_version.

# %% [markdown]
# ### **Access the initial data**

# %%
df.head()
# Out:
#    unnamed                                                app        category  \
# 0        0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1        1                                Coloring book moana  ART_AND_DESIGN
# 2        2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3        3                              Sketch - Draw & Paint  ART_AND_DESIGN
# 4        4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
#
#    rating  reviews  size     installs  type price content_rating  \
# 0     4.1      159  19.0      10,000+  Free     0       Everyone
# 1     3.9      967  14.0     500,000+  Free     0       Everyone
# 2     4.7    87510   8.7   5,000,000+  Free     0       Everyone
# 3     4.5   215644  25.0  50,000,000+  Free     0           Teen
# 4     4.3      967   2.8     100,000+  Free     0       Everyone
#
#                       genres      last_updated     current_version  \
# ...

# %% [markdown]
# ### **Handling missing values in rating and size column**

# %%
avg_rating = df['rating'].mean().round(1)
avg_size = df['size'].mean().round(2)

# %% [markdown]
# ### **Filling the missing values in rating and size column**

# %%
df['rating'] = df['rating'].fillna(avg_rating)
df['size'] = df['size'].fillna(avg_size)
df[['size', 'rating']].isna().sum()
# Out:
# size      0
# rating    0
# dtype: int64

# %% [markdown]
# now the missing values are handled

# %% [markdown]
# ### **Handling missing values in current_version and andriod_version**

# %%
most_frequent_current_version = df['current_version'].mode().values[0]
most_frequent_andriod_version = df['andriod_version'].mode().values[0]

# %% [markdown]
# ### **Filling missing values in current_version and andriod_version columns**

# %%
df['current_version'] = df['current_version'].fillna(most_frequent_current_version)
df['andriod_version'] = df['andriod_version'].fillna(most_frequent_andriod_version)
df[['current_version', 'andriod_version']].isna().sum()
# Out:
# current_version    0
# andriod_version    0
# dtype: int64

# %% [markdown]
# The missing values in current_version and andriod_version columns are properly handled.

# %% [markdown]
# ### **Check the missing values count in the dataframe**

# %%
df.isna().sum()
# Out:
# unnamed            0
# app                0
# category           0
# rating             0
# reviews            0
# size               0
# installs           0
# type               0
# price              0
# content_rating     0
# genres             0
# last_updated       0
# current_version    0
# andriod_version    0
# dtype: int64

# %% [markdown]
# ### **Check for duplicate rows in the dataframe**

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9654    False
# 9655    False
# 9656    False
# 9657    False
# 9658    False
# Length: 9659, dtype: bool

# %% [markdown]
# ### **Check for duplicate rows count in the dataframe**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate rows.

# %% [markdown]
# ### **Check the datatype of the columns**

# %%
df.dtypes
# Out:
# unnamed              int64
# app                 object
# category            object
# rating             float64
# reviews              int64
# size               float64
# installs            object
# type                object
# price               object
# content_rating      object
# genres              object
# last_updated        object
# current_version     object
# andriod_version     object
# dtype: object

# %% [markdown]
# ### **Access the installs column in the dataframe**

# %%
df.installs
# Out:
# 0           10,000+
# 1          500,000+
# 2        5,000,000+
# 3       50,000,000+
# 4          100,000+
#            ...
# 9654         5,000+
# 9655           100+
# 9656         1,000+
# 9657         1,000+
# 9658    10,000,000+
# Name: installs, Length: 9659, dtype: object

# %% [markdown]
# ### **Remove the commas and plus sign in installs column**

# %%
df['installs'] = df['installs'].str.replace('[+,]', '', regex = True).astype('int64')

# %% [markdown]
# ### **Ensure the installs column datatype is correct**

# %%
df.installs
# Out:
# 0          10000
# 1         500000
# 2        5000000
# 3       50000000
# 4         100000
#           ...
# 9654        5000
# 9655         100
# 9656        1000
# 9657        1000
# 9658    10000000
# Name: installs, Length: 9659, dtype: int64

# %% [markdown]
# ### **Access the price column**

# %%
df.price.unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %% [markdown]
# ### **Remove the dollar sign in the price column**

# %%
df['price'] = df['price'].str.replace('$', '').astype('float64')

# %% [markdown]
# ### **Ensure the price column is valid now**

# %%
df.price.unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %% [markdown]
# ### **Check all columns to confirm correct datatypes**

# %%
df.dtypes
# Out:
# unnamed              int64
# app                 object
# category            object
# rating             float64
# reviews              int64
# size               float64
# installs             int64
# type                object
# price              float64
# content_rating      object
# genres              object
# last_updated        object
# current_version     object
# andriod_version     object
# dtype: object

# %% [markdown]
# # **2. Category Exploration**

# %% [markdown]
# ### **Check app distribution across all categories**

# %%
category_counts = df['category'].value_counts()
category_counts
# Out:
# category
# FAMILY                 1832
# GAME                    959
# TOOLS                   827
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# HOUSE_AND_HOME           74
# EVENTS                   64
# ART_AND_DESIGN           64
# PARENTING                60
# COMICS                   56
# ...

# %% [markdown]
# ## **Visualize the category distribution to better understand the dataset**

# %%
plt.subplots(figsize=(25, 6))

plt.xlabel('Category Count')
plt.ylabel('Types of Categories')
plt.title('Apps Distribution Among All Categories')
plt.barh(category_counts.index, category_counts.values, color='skyblue')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# The Family category leads with the highest number of apps

# %% [markdown]
# # **3. Metrics Analysis**

# %% [markdown]
# ### **Visualise the distribution of rating among apps**

# %%
df['rating'].hist(bins = 10)
plt.show()

# %% [markdown]
# The distribution of app ratings reveals that most apps have ratings clustered around 4.0 to 4.6, indicating generally positive user feedback across the dataset.

# %% [markdown]
# ### **Check average rating and reviews among categories**

# %%
category_avg = df.groupby('category')[['rating','reviews']].mean()
category_avg.head(10)
# Out:
#                        rating        reviews
# category
# ART_AND_DESIGN       4.350000   22175.046875
# AUTO_AND_VEHICLES    4.191765   13690.188235
# BEAUTY               4.262264    7476.226415
# BOOKS_AND_REFERENCE  4.310360   75321.234234
# BUSINESS             4.136429   23548.202381
# COMICS               4.182143   41822.696429
# COMMUNICATION        4.136190  907337.676190
# DATING               4.019883   21190.315789
# EDUCATION            4.363025  112303.764706
# ENTERTAINMENT        4.135294  340810.294118

# %% [markdown]
# ### **Visualise the category average**

# %%
category_avg.plot(kind = 'bar', figsize = (12,6),color = 'blue')

plt.title('Average Rating and Review per Category')
plt.ylabel('Average Values')
plt.show()

# %% [markdown]
# The Social category leads with the highest average rating and reviews, followed by Communication, indicating strong user satisfaction and engagement in these categories.

# %% [markdown]
# ### **Average amount spent on paid apps**

# %%
paid_apps = df[df['type'] == 'Paid']
paid_avg = paid_apps.groupby('category')['price'].mean()
paid_avg
# Out:
# category
# ART_AND_DESIGN           1.990000
# AUTO_AND_VEHICLES        4.490000
# BOOKS_AND_REFERENCE      4.277500
# BUSINESS                14.607500
# COMMUNICATION            3.079259
# DATING                   4.573333
# EDUCATION                4.490000
# ENTERTAINMENT            3.990000
# EVENTS                 109.990000
# FAMILY                  13.113989
# FINANCE                170.637059
# FOOD_AND_DRINK           4.240000
# GAME                     3.467195
# HEALTH_AND_FITNESS       4.290000
# LIBRARIES_AND_DEMO       0.990000
# LIFESTYLE              124.256316
# MAPS_AND_NAVIGATION      5.390000
# MEDICAL                 11.996386
# NEWS_AND_MAGAZINES       1.990000
# PARENTING                4.790000
# PERSONALIZATION          1.857778
# PHOTOGRAPHY              6.225263
# PRODUCTIVITY             8.961786
# SHOPPING                 2.740000
# SOCIAL                   5.323333
# SPORTS                   4.166667
# TOOLS                    3.426282
# ...

# %% [markdown]
# ### **Visualise the average amount spent on paid apps**

# %%
plt.subplots(figsize = (20, 8))

plt.xlabel('Types of Categories')
plt.ylabel('Average Price')
plt.title('Average Price of Paid Apps by Category')

plt.xticks(rotation = 55)
plt.bar(paid_avg.index, paid_avg.values)
plt.show()

# %% [markdown]
# Based on the analysis, categories like Finance (average price: 170.64) and Lifestyle (average price: 124.26) have the highest average prices, while Libraries and Demo (0.99) and Personalization (1.86) have the lowest.

# %% [markdown]
# ### **Check relationship between installs and ratings**

# %%
plt.subplots(figsize=(8, 6))

plt.xlabel('Number of Installs')
plt.ylabel('Rating')
plt.title('Relationship between Installs and Ratings')

plt.hexbin(df['rating'], df['installs'], gridsize=30, cmap='Oranges', mincnt=1)
plt.colorbar(label='Count')
plt.show()

# %% [markdown]
# The scatter plot shows a weak relationship between the number of installs and app ratings, suggesting that high installs do not necessarily correlate with higher ratings, as apps with a wide range of installs have diverse ratings.m

# %% [markdown]
# ### **Check comparison of installs for Free vs. Paid Apps**

# %%
installs_type = df.groupby('type')['installs'].sum()
installs_type
# Out:
# type
# Free    75065572646
# Paid       57364881
# Name: installs, dtype: int64

# %% [markdown]
# ### **Visualize the comparison of installs_type**

# %%
plt.subplots(figsize = (12, 6))

types = ['Free', 'Paid']
plt.title('Proportion of Total Installs for Free vs. Paid Apps')

plt.pie(installs_type, labels = types, colors = ['orange', 'blue'], autopct = '%1.1f%%')
plt.axis('equal')
plt.legend()
plt.show()

# %% [markdown]
# The analysis reveals that free apps dominate the market, accounting for approximately 99.9% of total installs, while paid apps represent only about 0.1% of installs.

# %% [markdown]
# # 4. Sentiment **Analysis**

# %% [markdown]
# ### **Load the user_reviews dataset**

# %%
user_reviews = pd.read_csv('/content/user_reviews.csv')
user_reviews
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %% [markdown]
# ### **Renaming the columns in the dataset**

# %%
cols = {'App': 'app',
        'Translated_Review': 'translated_review',
        'Sentiment': 'sentiment',
        'Sentiment_Polarity': 'sentiment_polarity',
        'Sentiment_Subjectivity': 'sentiment_subjectivity'}
user_reviews.rename(columns = cols, inplace = True)

# %% [markdown]
# ### **Check for missing values count in the dataframe**

# %%
user_reviews.isna().sum()
# Out:
# app                           0
# translated_review         26868
# sentiment                 26863
# sentiment_polarity        26863
# sentiment_subjectivity    26863
# dtype: int64

# %% [markdown]
# ### **Handling missing values by dropna() method**

# %%
reviews = user_reviews.dropna()
reviews
# Out:
#                                   app  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        translated_review sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# ...

# %% [markdown]
# ### **Check missing values in reviews dataframe**

# %%
reviews.isna().sum()
# Out:
# app                       0
# translated_review         0
# sentiment                 0
# sentiment_polarity        0
# sentiment_subjectivity    0
# dtype: int64

# %%
reviews.head()
# Out:
#                      app                                  translated_review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
#
#   sentiment  sentiment_polarity  sentiment_subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000

# %% [markdown]
# ### **Check the distribution of sentiment labels**

# %%
sentiment = reviews['sentiment'].value_counts()
sentiment
# Out:
# sentiment
# Positive    23998
# Negative     8271
# Neutral      5158
# Name: count, dtype: int64

# %% [markdown]
# ### **Visualise the distribution of sentiment labels**

# %%
plt.figure(figsize=(8, 8))

plt.title('Distribution of Sentiment Labels')
plt.pie(sentiment.values, labels=sentiment.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'orange', 'lightgreen'])

plt.show()

# %% [markdown]
# The analysis reveals that positive reviews dominate the dataset, followed by negative and neutral reviews, suggesting a largely favorable sentiment among users.

# %% [markdown]
# ### **Ignore Warnings**

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
reviews = pd.DataFrame({
    'sentiment': ['positive', 'negative', 'neutral', 'positive', 'negative'],
    'sentiment_polarity': [0.8, -0.6, 0.0, 0.7, -0.4]
})

# %% [markdown]
# ### **Visualise the sentiment polarity by sentiment**

# %%
plt.figure(figsize=(10, 6))
plt.xlabel('Sentiment')
plt.ylabel('Sentiment Polarity')
plt.title('Sentiment Polarity Distribution')
sns.violinplot(x='sentiment', y='sentiment_polarity', data=reviews, palette='Blues')
plt.show()

# %% [markdown]
# The violin plot shows **positive reviews** clustering near high sentiment polarity scores (close to 1), reflecting strong positivity. **Negative reviews** concentrate around low polarity values (around -0.75), indicating strong negativity. **Neutral reviews** display limited variability or density, suggesting a narrow range of scores or insufficient data for this category.

# %% [markdown]
# ### **Merge the two datasets**

# %%
merged_df = pd.merge(df, user_reviews, on = 'app', how='inner')
merged_df.head()
# Out:
#    unnamed                  app        category  rating  reviews  size  \
# 0        1  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0
# 1        1  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0
# 2        1  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0
# 3        1  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0
# 4        1  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0
#
#    installs  type  price content_rating                     genres  \
# 0    500000  Free    0.0       Everyone  Art & Design;Pretend Play
# 1    500000  Free    0.0       Everyone  Art & Design;Pretend Play
# 2    500000  Free    0.0       Everyone  Art & Design;Pretend Play
# 3    500000  Free    0.0       Everyone  Art & Design;Pretend Play
# 4    500000  Free    0.0       Everyone  Art & Design;Pretend Play
#
#        last_updated current_version andriod_version  \
# 0  January 15, 2018           2.0.0    4.0.3 and up
# ...

# %% [markdown]
# ### **Calculate the average sentiment polarity for each category**

# %%
avg_sentiment = merged_df.groupby('category')['sentiment_polarity'].mean()
avg_sentiment.sort_values(ascending = False)
# Out:
# category
# COMICS                 0.440031
# EVENTS                 0.377933
# AUTO_AND_VEHICLES      0.348683
# PARENTING              0.318880
# WEATHER                0.294978
# HEALTH_AND_FITNESS     0.290694
# EDUCATION              0.279332
# PERSONALIZATION        0.278213
# MAPS_AND_NAVIGATION    0.267218
# FOOD_AND_DRINK         0.266882
# BOOKS_AND_REFERENCE    0.248422
# LIBRARIES_AND_DEMO     0.240771
# HOUSE_AND_HOME         0.235704
# ART_AND_DESIGN         0.234735
# BUSINESS               0.232189
# MEDICAL                0.224071
# PHOTOGRAPHY            0.222888
# LIFESTYLE              0.215944
# TOOLS                  0.214037
# SHOPPING               0.196435
# TRAVEL_AND_LOCAL       0.194810
# BEAUTY                 0.193360
# SPORTS                 0.192511
# PRODUCTIVITY           0.184225
# DATING                 0.178846
# COMMUNICATION          0.177275
# FINANCE                0.170783
# VIDEO_PLAYERS          0.143543
# ENTERTAINMENT          0.131206
# ...

# %% [markdown]
# ### **Visualise the top 10 average sentiment polarity**

# %%
top_10 = avg_sentiment.head(10)

plt.xlabel('Average Sentiment Polarity')
plt.ylabel('Category')
plt.title('Average Sentiment Polarity by Category (Top 10)')

plt.barh(top_10.index, top_10.values)
plt.show()

# %% [markdown]
# The analysis reveals that the Comics category has the highest average sentiment polarity, followed by Events and Auto and Vehicles.

# %% [markdown]
# The task of Unveiling the Android App Market has been successfully completed.
